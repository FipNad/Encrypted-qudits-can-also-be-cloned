# %% [markdown]
# Let $\ket{\psi}$ be a qudit state, $\ket{\Phi_d}$ be the generalized Bell state, $X_d, Z_d$ the generalized Pauli operators, and $C = \left(I_d \otimes I_d\otimes F^2\right) \cdot \left(I_d\otimes\sum_{c=0}^{d-1}X_d^2 \otimes \ket{c}\bra{c}\right)$.
#     For any $d\geq2$, the following equality is true.
#     $$
#     \begin{align*}
#     C\cdot\frac{1}{d}\sum_{m,n=0}^{d-1}\Big(\left(X_d^{m}Z_d^{n}\right)\ket{\psi} \otimes \left(X_d^{m}Z_d^{n} \otimes I_d\right)\ket{\Phi_d}\Big)
#     =\frac{1}{\sqrt{d}}\left(\sum_{p=0}^{d-1}\ket{p}\ket{p}\right)\ket{\psi}
#     \end{align*}
#     $$

# %%
import sys
import os
import numpy as np
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from QuditGates import QuditGates
from QuditCircuit import QuditCircuit
from helper_functions import *

# %%
dimension = 5
gates = QuditGates(dimension)

# %%
X = gates.get_X_gate()
Z = gates.get_Z_gate()
I = gates.get_I_gate()

BELL_STATE = vector_to_ket(create_maximally_entangled_state(dimension))

# Create the random pure state |psi>
PSI = vector_to_ket(random_pure_state(dimension))

# Initialize the LHS and RHS of the equation to be verified
LHS = np.zeros((dimension**3, 1), dtype=np.complex128)
RHS = vector_to_ket(np.kron(BELL_STATE, PSI))

# %%
for m in range(dimension):
    for n in range(dimension):
        psi_matrix = np.linalg.matrix_power(X, m) @ np.linalg.matrix_power(Z, n)
        bell_matrix = np.kron((np.linalg.matrix_power(X, m) @ np.linalg.matrix_power(Z, -n)), I)
        left_term = psi_matrix @ PSI
        right_term = bell_matrix @ BELL_STATE

        term = np.kron(left_term, right_term)

        LHS += (1/dimension)* term

# %%
print("LHS:")
display_state_abs(LHS, dimension, 3)
print("\n")
print("RHS:")
display_state_abs(RHS, dimension, 3)
print("\n")
print(f"The LHS and RHS are equal: {np.allclose(LHS, RHS)}")
# Out:
# LHS:
# |000> : 0.1607+0.2388j => |000|=0.2878 => Prob=0.0828
# |001> : 0.0368+0.1530j => |001|=0.1574 => Prob=0.0248
# |002> : 0.0084+0.0580j => |002|=0.0586 => Prob=0.0034
# |003> : 0.2024+0.1482j => |003|=0.2509 => Prob=0.0629
# |004> : 0.1483+0.0636j => |004|=0.1614 => Prob=0.0260
# |110> : 0.1607+0.2388j => |110|=0.2878 => Prob=0.0828
# |111> : 0.0368+0.1530j => |111|=0.1574 => Prob=0.0248
# |112> : 0.0084+0.0580j => |112|=0.0586 => Prob=0.0034
# |113> : 0.2024+0.1482j => |113|=0.2509 => Prob=0.0629
# |114> : 0.1483+0.0636j => |114|=0.1614 => Prob=0.0260
# |220> : 0.1607+0.2388j => |220|=0.2878 => Prob=0.0828
# |221> : 0.0368+0.1530j => |221|=0.1574 => Prob=0.0248
# |222> : 0.0084+0.0580j => |222|=0.0586 => Prob=0.0034
# |223> : 0.2024+0.1482j => |223|=0.2509 => Prob=0.0629
# |224> : 0.1483+0.0636j => |224|=0.1614 => Prob=0.0260
# |330> : 0.1607+0.2388j => |330|=0.2878 => Prob=0.0828
# |331> : 0.0368+0.1530j => |331|=0.1574 => Prob=0.0248
# |332> : 0.0084+0.0580j => |332|=0.0586 => Prob=0.0034
# |333> : 0.2024+0.1482j => |333|=0.2509 => Prob=0.0629
# |334> : 0.1483+0.0636j => |334|=0.1614 => Prob=0.0260
# |440> : 0.1607+0.2388j => |440|=0.2878 => Prob=0.0828
# |441> : 0.0368+0.1530j => |441|=0.1574 => Prob=0.0248
# |442> : 0.0084+0.0580j => |442|=0.0586 => Prob=0.0034
# |443> : 0.2024+0.1482j => |443|=0.2509 => Prob=0.0629
# |444> : 0.1483+0.0636j => |444|=0.1614 => Prob=0.0260
#
#
# RHS:
# |000> : 0.1607+0.2388j => |000|=0.2878 => Prob=0.0828
# |001> : 0.0368+0.1530j => |001|=0.1574 => Prob=0.0248
# |002> : 0.0084+0.0580j => |002|=0.0586 => Prob=0.0034
# |003> : 0.2024+0.1482j => |003|=0.2509 => Prob=0.0629
# |004> : 0.1483+0.0636j => |004|=0.1614 => Prob=0.0260
# |110> : 0.1607+0.2388j => |110|=0.2878 => Prob=0.0828
# |111> : 0.0368+0.1530j => |111|=0.1574 => Prob=0.0248
# |112> : 0.0084+0.0580j => |112|=0.0586 => Prob=0.0034
# |113> : 0.2024+0.1482j => |113|=0.2509 => Prob=0.0629
# |114> : 0.1483+0.0636j => |114|=0.1614 => Prob=0.0260
# |220> : 0.1607+0.2388j => |220|=0.2878 => Prob=0.0828
# |221> : 0.0368+0.1530j => |221|=0.1574 => Prob=0.0248
# |222> : 0.0084+0.0580j => |222|=0.0586 => Prob=0.0034
# |223> : 0.2024+0.1482j => |223|=0.2509 => Prob=0.0629
# |224> : 0.1483+0.0636j => |224|=0.1614 => Prob=0.0260
# |330> : 0.1607+0.2388j => |330|=0.2878 => Prob=0.0828
# |331> : 0.0368+0.1530j => |331|=0.1574 => Prob=0.0248
# |332> : 0.0084+0.0580j => |332|=0.0586 => Prob=0.0034
# |333> : 0.2024+0.1482j => |333|=0.2509 => Prob=0.0629
# |334> : 0.1483+0.0636j => |334|=0.1614 => Prob=0.0260
# |440> : 0.1607+0.2388j => |440|=0.2878 => Prob=0.0828
# |441> : 0.0368+0.1530j => |441|=0.1574 => Prob=0.0248
# |442> : 0.0084+0.0580j => |442|=0.0586 => Prob=0.0034
# |443> : 0.2024+0.1482j => |443|=0.2509 => Prob=0.0629
# |444> : 0.1483+0.0636j => |444|=0.1614 => Prob=0.0260
#
#
# The LHS and RHS are equal: True
