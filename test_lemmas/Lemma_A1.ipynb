# %% [markdown]
# For any operator $U\in \mathcal{M}_{\mathbb{C}^{d}\times \mathbb{C}^d}$, the following equality is true.
#     $$[
#     (U\otimes I_d)\ket{\Phi_d} = (I_d\otimes U^{\mathsf{T}})\ket{\Phi_d}
#     ]$$

# %%
import sys
import os
import numpy as np
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from QuditGates import QuditGates
from QuditCircuit import QuditCircuit
from helper_functions import *

# %%
dimension = 5
gates = QuditGates(dimension)

# %%
I = gates.get_I_gate()
U = gates.get_random_unitary()
quantum_state = create_maximally_entangled_state(dimension)

LHS = np.kron(U, I) @ quantum_state
RHS = np.kron(I, U.T) @ quantum_state

# %%
print("LHS:", LHS)
print("\n")
print("RHS:", RHS)
print("\n")
print(f"The LHS and RHS are equal: {np.allclose(LHS, RHS)}")
# Out:
# LHS: [[ 0.09043756+0.15944009j]
#  [-0.08739349-0.26429691j]
#  [ 0.10185017-0.09276216j]
#  [ 0.22154163+0.12715338j]
#  [ 0.01840855+0.065906j  ]
#  [ 0.09167124+0.21049634j]
#  [ 0.21991941+0.08438598j]
#  [ 0.10810191-0.14964623j]
#  [ 0.01017904-0.17469556j]
#  [ 0.11948952-0.11323525j]
#  [ 0.15969754+0.1000566j ]
#  [ 0.07704994-0.04261927j]
#  [-0.1278163 +0.22343417j]
#  [-0.0360078 -0.09794205j]
#  [ 0.09616788+0.26520741j]
#  [ 0.14155819+0.14771319j]
#  [-0.04995596+0.12352669j]
#  [-0.12317419+0.17884348j]
#  [ 0.06634103+0.17565319j]
#  [-0.00565554-0.24071482j]
#  [ 0.15692055+0.10812488j]
#  [-0.14432183+0.14383204j]
#  [ 0.1621345 -0.08507294j]
#  [-0.22079433+0.09609709j]
#  [-0.11916172+0.12829341j]]
#
#
# RHS: [[ 0.09043756+0.15944009j]
#  [-0.08739349-0.26429691j]
#  [ 0.10185017-0.09276216j]
#  [ 0.22154163+0.12715338j]
#  [ 0.01840855+0.065906j  ]
#  [ 0.09167124+0.21049634j]
#  [ 0.21991941+0.08438598j]
#  [ 0.10810191-0.14964623j]
#  [ 0.01017904-0.17469556j]
#  [ 0.11948952-0.11323525j]
#  [ 0.15969754+0.1000566j ]
#  [ 0.07704994-0.04261927j]
#  [-0.1278163 +0.22343417j]
#  [-0.0360078 -0.09794205j]
#  [ 0.09616788+0.26520741j]
#  [ 0.14155819+0.14771319j]
#  [-0.04995596+0.12352669j]
#  [-0.12317419+0.17884348j]
#  [ 0.06634103+0.17565319j]
#  [-0.00565554-0.24071482j]
#  [ 0.15692055+0.10812488j]
#  [-0.14432183+0.14383204j]
#  [ 0.1621345 -0.08507294j]
#  [-0.22079433+0.09609709j]
#  [-0.11916172+0.12829341j]]
#
#
# The LHS and RHS are equal: True
