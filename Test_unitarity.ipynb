# %%
import numpy as np
from QuditGates import QuditGates
from QuditCircuit import QuditCircuit
from helper_functions import *

# %%
dimension = 5
number_S_qudits = 3
gates = QuditGates(dimension)

# %%
U_enc = gates.create_Uencryption(number_S_qudits)
U_dec = gates.create_Udecryption(number_S_qudits)

# %%
print(f"U_encryption is unitary: {is_unitary(U_enc)}")
# Out:
# U_encryption is unitary: True

# %%
print(f"U_decryption is unitary: {is_unitary(U_dec)}")
# Out:
# U_decryption is unitary: True
