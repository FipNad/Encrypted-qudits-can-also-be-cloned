# %% [markdown]
# The following identity
#     $$
#     \Big({X_d^{\scriptscriptstyle(Q_1)}}^{k_1}{Z_d^{\scriptscriptstyle(Q_1)}}^{-k_2} \otimes {X_d^{\scriptscriptstyle(Q_2)}}^{k_1}{Z_d^{\scriptscriptstyle(Q_2)}}^{k_2}\Big)\ket{\Phi_d}=\ket{\Phi_d}
#     $$
#
# holds for any $d\geq 2$ and $k_1,k_2 \in \{0\dots d-1\}$, where $Q_1, Q_2$ represent the two qudits involved.

# %%
import sys
import os
import numpy as np
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from QuditGates import QuditGates
from QuditCircuit import QuditCircuit
from helper_functions import *

# %%
dimension = 5
gates = QuditGates(dimension)

# %%
X = gates.get_X_gate()
Z = gates.get_Z_gate()
I = gates.get_I_gate()
BELL_STATE = vector_to_ket(create_maximally_entangled_state(dimension))

# %%
for k1 in range(dimension):
    for k2 in range(dimension):
        left_op = np.linalg.matrix_power(X, k1) @ np.linalg.matrix_power(Z, -k2)
        right_op = np.linalg.matrix_power(X, k1) @ np.linalg.matrix_power(Z, k2)
        op = np.kron(left_op, right_op)
        result = op @ BELL_STATE
        print(f"Result for (k1={k1}, k2={k2}): {np.allclose(result, BELL_STATE)}")
# Out:
# Result for (k1=0, k2=0): True
# Result for (k1=0, k2=1): True
# Result for (k1=0, k2=2): True
# Result for (k1=0, k2=3): True
# Result for (k1=0, k2=4): True
# Result for (k1=1, k2=0): True
# Result for (k1=1, k2=1): True
# Result for (k1=1, k2=2): True
# Result for (k1=1, k2=3): True
# Result for (k1=1, k2=4): True
# Result for (k1=2, k2=0): True
# Result for (k1=2, k2=1): True
# Result for (k1=2, k2=2): True
# Result for (k1=2, k2=3): True
# Result for (k1=2, k2=4): True
# Result for (k1=3, k2=0): True
# Result for (k1=3, k2=1): True
# Result for (k1=3, k2=2): True
# Result for (k1=3, k2=3): True
# Result for (k1=3, k2=4): True
# Result for (k1=4, k2=0): True
# Result for (k1=4, k2=1): True
# Result for (k1=4, k2=2): True
# Result for (k1=4, k2=3): True
# Result for (k1=4, k2=4): True
